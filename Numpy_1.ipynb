# %%
import numpy as np

# %%
myarr = np.array([[3,6,632,78]])

# %%
myarr
# Out:
# array([[  3,   6, 632,  78]])

# %%
myarr[0,1]
# Out:
# np.int64(6)

# %%
myarr[0,3]
# Out:
# np.int64(78)

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.4.6

# %%
a= [1,2,3]
a.shape
